# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

def plot_test():
    # 1.0 
    x = np.linspace(-np.pi, np.pi, 50)
    C, S = np.cos(x), np.sin(x)

    plt.plot(x, C, color='blue', linewidth=2.0, linestyle='-')
    plt.plot(x, S, color='red', linewidth=2.0, linestyle='-')
    plt.scatter(C, S, color='black', linewidth=0.01, linestyle='-')

    plt.xlim(x.min() * 1.1, x.max() * 1.1)
    plt.ylim(C.min() * 1.1, C.max() * 1.1)
    plt.show()

# 1.1 
def imshow_test():
    rd = np.random.randint(0,256,(64,128))
    print(rd)
    plt.imshow(rd)
    # plt.show()

plot_test()
imshow_test()
# Out:
# [[134  61  99 ... 148 161  41]
#  [151 209  18 ...  84  20  18]
#  [160  74 157 ...   8 165 170]
#  ...
#  [ 78 104 177 ...  74  32  84]
#  [241 181 175 ... 255  82   6]
#  [ 46 184 243 ...  97  45  23]]
